# %%
# Let's begin by importing what we'll need (You'll probably be copying and pasting this a lot)

# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats librayr from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/__init__.py:874: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# First of all, source of information for what a histogram actually is:
# http://en.wikipedia.org/wiki/Histogram

# %%
#Create a random normal-dist dataset
dataset1 = randn(100)

#Plot a histogram of the dataset, note bins=10 by default
plt.hist(dataset1)
# Out:
# (array([ 3.,  8.,  7., 11., 18., 18., 15., 13.,  3.,  4.]),
#  array([-2.23189628, -1.77006283, -1.30822939, -0.84639594, -0.38456249,
#          0.07727095,  0.5391044 ,  1.00093784,  1.46277129,  1.92460473,
#          2.38643818]),
#  <a list of 10 Patch objects>)

# %%
# Lets make another dataset
dataset2 = randn(80)

#Plot
plt.hist(dataset2,color='indianred')
# Out:
# (array([ 3.,  4.,  6., 16., 15.,  9., 11.,  8.,  6.,  2.]),
#  array([-2.26469653, -1.79237365, -1.32005077, -0.8477279 , -0.37540502,
#          0.09691786,  0.56924074,  1.04156362,  1.5138865 ,  1.98620937,
#          2.45853225]),
#  <a list of 10 Patch objects>)

# %%
# We can use normed to plot on same plot

# Set normed=True for the plots to be normalized in order to comapre data sets with different number of observations
# Set alpha=0.5 for transperancy

plt.hist(dataset1,normed=True,color='indianred',alpha=0.5,bins=20)
plt.hist(dataset2,normed=True,alpha=0.5,bins=20)
# Out:
# (array([0.10585979, 0.05292989, 0.05292989, 0.15878968, 0.15878968,
#         0.15878968, 0.37050926, 0.47636905, 0.31757937, 0.47636905,
#         0.26464947, 0.21171958, 0.37050926, 0.21171958, 0.21171958,
#         0.21171958, 0.31757937, 0.        , 0.05292989, 0.05292989]),
#  array([-2.26469653, -2.02853509, -1.79237365, -1.55621221, -1.32005077,
#         -1.08388934, -0.8477279 , -0.61156646, -0.37540502, -0.13924358,
#          0.09691786,  0.3330793 ,  0.56924074,  0.80540218,  1.04156362,
#          1.27772506,  1.5138865 ,  1.75004794,  1.98620937,  2.22237081,
#          2.45853225]),
#  <a list of 20 Patch objects>)

# %%
# Make two more random normal dist data sets
data1 = randn(1000)
data2 = randn(1000)

#Can represent joint distributions using joint plots
sns.jointplot(data1,data2)
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/__init__.py:894: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-fd721c346e38> in <module>()
#       4
#       5 #Can represent joint distributions using joint plots
# ----> 6 sns.jointplot(data1,data2)
#
# /usr/lib/python2.7/dist-packages/seaborn/distributions.pyc in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#     803         marginal_kws.setdefault("kde", False)
#     804         marginal_kws.setdefault("color", color)
# --> 805         grid.plot_marginals(distplot, **marginal_kws)
#     806
#     807     elif kind.startswith("hex"):
#
# /usr/lib/python2.7/dist-packages/seaborn/axisgrid.pyc in plot_marginals(self, func, **kwargs)
#    1728         kwargs["vertical"] = False
#    1729         plt.sca(self.ax_marg_x)
# -> 1730         func(self.x, **kwargs)
#    1731
#    1732         kwargs["vertical"] = True
#
# /usr/lib/python2.7/dist-packages/seaborn/distributions.pyc in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     210         hist_color = hist_kws.pop("color", color)
#     211         ax.hist(a, bins, orientation=orientation,
# --> 212                 color=hist_color, **hist_kws)
#     213         if hist_color != color:
#     214             hist_kws["color"] = hist_color
#
# /usr/lib/python2.7/dist-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1812                     warnings.warn(msg % (label_namer, func.__name__),
#    1813                                   RuntimeWarning, stacklevel=2)
# -> 1814             return func(ax, *args, **kwargs)
#    1815         pre_doc = inner.__doc__
#    1816         if pre_doc is None:
#
# /usr/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6008             # this will automatically overwrite bins,
#    6009             # so that each histogram uses the same bins
# -> 6010             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6011             m = m.astype(float)  # causes problems later if it's an int
#    6012             if mlast is None:
#
# /home/sudhanshu/.local/lib/python2.7/site-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     717         except TypeError:
#     718             raise TypeError(
# --> 719                 '`bins` must be an integer, a string, or an array')
#     720         if n_equal_bins < 1:
#     721             raise ValueError('`bins` must be positive, when an integer')
#
# TypeError: `bins` must be an integer, a string, or an array

# %%
# Can also use hex bins for a more concise picture
sns.jointplot(data1,data2,kind='hex')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-c6dbb01ab3d7> in <module>()
#       1 # Can also use hex bins for a more concise picture
# ----> 2 sns.jointplot(data1,data2,kind='hex')
#
# /usr/lib/python2.7/dist-packages/seaborn/distributions.pyc in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#     817         marginal_kws.setdefault("kde", False)
#     818         marginal_kws.setdefault("color", color)
# --> 819         grid.plot_marginals(distplot, **marginal_kws)
#     820
#     821     elif kind.startswith("kde"):
#
# /usr/lib/python2.7/dist-packages/seaborn/axisgrid.pyc in plot_marginals(self, func, **kwargs)
#    1728         kwargs["vertical"] = False
#    1729         plt.sca(self.ax_marg_x)
# -> 1730         func(self.x, **kwargs)
#    1731
#    1732         kwargs["vertical"] = True
#
# /usr/lib/python2.7/dist-packages/seaborn/distributions.pyc in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax)
#     210         hist_color = hist_kws.pop("color", color)
#     211         ax.hist(a, bins, orientation=orientation,
# --> 212                 color=hist_color, **hist_kws)
#     213         if hist_color != color:
#     214             hist_kws["color"] = hist_color
#
# /usr/lib/python2.7/dist-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1812                     warnings.warn(msg % (label_namer, func.__name__),
#    1813                                   RuntimeWarning, stacklevel=2)
# -> 1814             return func(ax, *args, **kwargs)
#    1815         pre_doc = inner.__doc__
#    1816         if pre_doc is None:
#
# /usr/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in hist(self, x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6008             # this will automatically overwrite bins,
#    6009             # so that each histogram uses the same bins
# -> 6010             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6011             m = m.astype(float)  # causes problems later if it's an int
#    6012             if mlast is None:
#
# /home/sudhanshu/.local/lib/python2.7/site-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     717         except TypeError:
#     718             raise TypeError(
# --> 719                 '`bins` must be an integer, a string, or an array')
#     720         if n_equal_bins < 1:
#     721             raise ValueError('`bins` must be positive, when an integer')
#
# TypeError: `bins` must be an integer, a string, or an array

# %%
# Next we'll learn how to use Kernel Estimation Plots
